prg5 = set(prg5)

prg6 = ['B72604R8089', 'B72604R8117', 'B72604R8123', 'B72604R8100', 'B72604R8080', 'B52501R8003', 'B72604R8114', 'B72604R8138', 'B72604R8010', 'B72604R8094', 'R72604R8035', 'B72604R8011', 'B72604R8096', 'B52501R80209', 'B72604R8098', 'B72604R8121', 'B52501R8221', 'B72604R8095', 'B72604R8102', 'B72604R8061', 'B72604R8055', 'B72604R8009', 'B72604R8120', 'B72604R8146', 'B72604R8054', 'B72604R8045', 'B72604R8039', 'B72604R8129', 'B72604R8040', 'B72604R8143', 'B52501R8567', 'B72604R8053', 'B72604R8077', 'B72604R8041', 'B72604R8028', 'B72604R8070', 'B52501R8192', 'B72604R8113', 'B72604R8035', 'B72604R8032']
prg6 = set(prg6)

# %%
over3.difference(over6)
# Out:
# {'B52501R8005',
#  'B52501R8181',
#  'B72604R8006',
#  'B72604R8012',
#  'B72604R8035',
#  'B72604R8043',
#  'B72604R8044',
#  'B72604R8057',
#  'B72604R8061',
#  'B72604R8064',
#  'B72604R8067',
#  'B72604R8082',
#  'B72604R8087',
#  'B72604R8112',
#  'B72604R8118',
#  'B72604R8122',
#  'B72604R813',
#  'B72604R8134'}

# %%
over5.difference(over6)
# Out:
# {'B52501R8181', 'B72604R8012', 'B72604R8043', 'B72604R8118', 'B72604R8122'}

# %%
over4.difference(over5)
# Out:
# {'B52501R8005',
#  'B72604R8006',
#  'B72604R8035',
#  'B72604R8044',
#  'B72604R8057',
#  'B72604R8064',
#  'B72604R8067',
#  'B72604R8087',
#  'B72604R8112',
#  'B72604R8134'}

# %%
over3.difference(over4)
# Out:
# {'B72604R8061', 'B72604R8082', 'B72604R813'}

# %%
prg3.difference(prg6)
# Out:
# {'B52501R8005',
#  'B52501R8181',
#  'B72604R8006',
#  'B72604R8012',
#  'B72604R8043',
#  'B72604R8044',
#  'B72604R8047',
#  'B72604R8048',
#  'B72604R8057',
#  'B72604R8064',
#  'B72604R8067',
#  'B72604R8082',
#  'B72604R8087',
#  'B72604R8112',
#  'B72604R8118',
#  'B72604R8122',
#  'B72604R813',
#  'B72604R8134'}

# %%
prg5.difference(prg6)
# Out:
# {'B52501R8181', 'B72604R8012', 'B72604R8043', 'B72604R8118', 'B72604R8122'}

# %%
prg4.difference(prg5)
# Out:
# {'B52501R8005',
#  'B72604R8006',
#  'B72604R8044',
#  'B72604R8057',
#  'B72604R8064',
#  'B72604R8067',
#  'B72604R8087',
#  'B72604R8112',
#  'B72604R8134'}

# %%
prg3.difference(prg4)
# Out:
# {'B72604R8047', 'B72604R8048', 'B72604R8082', 'B72604R813'}

# %%
over_main = set(['B72604R8143', 'B72604R8041', 'B72604R8080', 'R72604R8035', 'B72604R8089', 'B72604R8121', 'B72604R8053', 'B72604R8114', 'B72604R8030', 'B72604R8131', 'B72604R8102', 'B72604R8100', 'B72604R8044', 'B72604R8040', 'B72604R8067', 'B52501R8181', 'B72604R8123', 'B72604R8122', 'B72604R813', 'B72604R8077', 'B72604R8039', 'B72604R8129', 'B72604R8120', 'B72604R8054', 'B72604R8055', 'B72604R8045', 'B72604R8113', 'B72604R8011', 'B72604R8070', 'B52501R8003', 'B72604R8061', 'B52501R8192', 'B72604R8094', 'B52501R8137', 'B72604R8009', 'B72604R8098', 'B52501R8221', 'B72604R8117', 'B72604R8010', 'B72604R8146', 'B72604R8035', 'B72604R8095', 'B52501R80209', 'B52501R8567', 'B72604R8096'])

# %%
over3.difference(over_main)
# Out:
# {'B52501R8005',
#  'B72604R8006',
#  'B72604R8012',
#  'B72604R8028',
#  'B72604R8032',
#  'B72604R8034',
#  'B72604R8043',
#  'B72604R8047',
#  'B72604R8048',
#  'B72604R8057',
#  'B72604R8064',
#  'B72604R8082',
#  'B72604R8087',
#  'B72604R8112',
#  'B72604R8118',
#  'B72604R8134',
#  'B72604R8138'}

# %%
over_main.difference(over3)
# Out:
# {'B52501R8137', 'B72604R8131'}

# %%
over3
# Out:
# {'B52501R8003',
#  'B52501R8005',
#  'B52501R80209',
#  'B52501R8181',
#  'B52501R8192',
#  'B52501R8221',
#  'B52501R8567',
#  'B72604R8006',
#  'B72604R8009',
#  'B72604R8010',
#  'B72604R8011',
#  'B72604R8012',
#  'B72604R8028',
#  'B72604R8030',
#  'B72604R8032',
#  'B72604R8034',
#  'B72604R8035',
#  'B72604R8039',
#  'B72604R8040',
#  'B72604R8041',
#  'B72604R8043',
#  'B72604R8044',
#  'B72604R8045',
#  'B72604R8047',
#  'B72604R8048',
#  'B72604R8053',
#  'B72604R8054',
#  'B72604R8055',
#  'B72604R8057',
#  'B72604R8061',
#  'B72604R8064',
#  'B72604R8067',
#  'B72604R8070',
#  'B72604R8077',
#  'B72604R8080',
#  'B72604R8082',
#  'B72604R8087',
#  'B72604R8089',
#  'B72604R8094',
#  'B72604R8095',
#  'B72604R8096',
#  'B72604R8098',
#  'B72604R8100',
#  'B72604R8102',
#  'B72604R8112',
#  'B72604R8113',
#  'B72604R8114',
#  'B72604R8117',
#  'B72604R8118',
#  'B72604R8120',
#  'B72604R8121',
#  'B72604R8122',
#  'B72604R8123',
#  'B72604R8129',
#  'B72604R813',
# ...

# %%
over3.difference(prg3)
# Out:
# {'B72604R8030', 'B72604R8034'}

# %%
prg3.difference(over3)
# Out:
# set()

# %%
l = ['B72604R8006', 'B72604R8044', 'B72604R8121', 'B72604R8095', 'B72604R8070', 'B72604R8035', 'B72604R8112', 'B52501R8181', 'R72604R8035', 'B72604R8057', 'B72604R8048', 'B72604R8096', 'B72604R8138', 'B72604R8011', 'B52501R8221', 'B72604R8041', 'B72604R8146', 'B72604R8134', 'B72604R8122', 'B72604R8087', 'B52501R80209', 'B72604R8045', 'B72604R8067', 'B72604R8094', 'B72604R8100', 'B72604R8120', 'B72604R8055', 'B72604R813', 'B72604R8089', 'B72604R8118', 'B72604R8082', 'B52501R8567', 'B72604R8080', 'B72604R8009', 'B72604R8061', 'B72604R8054', 'B52501R8005', 'B72604R8098', 'B72604R8030', 'B72604R8028', 'B72604R8039', 'B72604R8032', 'B72604R8143', 'B72604R8129', 'B72604R8114', 'B72604R8113', 'B72604R8010', 'B72604R8047', 'B72604R8102', 'B72604R8012', 'B72604R8053', 'B72604R8077', 'B52501R8192', 'B72604R8043', 'B72604R8064', 'B72604R8123', 'B72604R8117', 'B72604R8034', 'B72604R8040', 'B52501R8003']

l = set(l)
print(len(l))
over3.difference(l)
l.difference(over3)
# Out:
# 60
# set()

# %%
s = ['B52501R8128', 'B72604R8006', 'B72604R8044', 'B72604R8121', 'B52501R80223', 'B72604R8095', 'B72604R8070', 'B72604R8035', 'B52501R8181', 'R72604R8035', 'B72604R8048', 'B72604R8096', 'B72604R8138', 'B72604R8011', 'B52501R8221', 'B72604R8041', 'B72604R8146', 'B72604R8122', 'B72604R8087', 'B52501R80209', 'B72604R8045', 'B72604R8067', 'B72604R8094', 'B72604R8100', 'B52501R80246', 'B52501R8137', 'B72604R8120', 'B72604R8055', 'B72604R813', 'B72604R8089', 'B72604R8080', 'B72604R8061', 'B52501R8567', 'B72604R8054', 'B72604R8009', 'B72604R8098', 'B72604R8030', 'B72604R8039', 'B72604R8032', 'B72604R8131', 'B72604R8143', 'B72604R8129', 'B72604R8114', 'B72604R8113', 'B72604R8010', 'B72604R8047', 'B72604R8102', 'B72604R8012', 'B72604R8053', 'B72604R8077', 'B52501R8192', 'B72604R8043', 'B72604R8064', 'B72604R8123', 'B72604R8117', 'B72604R8034', 'B72604R8015', 'B72604R8040', 'B52501R8003']
s = set(s)

s.difference(l)
# Out:
# {'B52501R80223',
#  'B52501R80246',
#  'B52501R8128',
#  'B52501R8137',
#  'B72604R8015',
#  'B72604R8131'}

# %% [markdown]
# B52501R80223 looks fine
# B52501R80246 looks fine
# B52501R8128 looks fine
# B52501R8137 looks fine
# B72604R8015 bad chip
# B72604R8131 looks fine

# %%
l.difference(s)
# Out:
# {'B52501R8005',
#  'B72604R8028',
#  'B72604R8057',
#  'B72604R8082',
#  'B72604R8112',
#  'B72604R8118',
#  'B72604R8134'}

# %%
d = ['B52501R8128', 'B52501R8139', 'B72604R8006', 'B72604R8044', 'B72604R8121', 'B52501R80223', 'B72604R8095', 'B72604R8070', 'B52501R8016', 'B72604R8016', 'B72604R8112', 'B52501R8181', 'R72604R8035', 'B72604R8035', 'B72604R8057', 'B72604R8048', 'B72604R8096', 'B72604R8138', 'B72604R8011', 'B52501R8221', 'B72604R8041', 'B72604R8146', 'B72604R8134', 'B72604R8122', 'B72604R8087', 'B52501R80209', 'B72604R8027', 'B72604R8045', 'B72604R8067', 'B52501R8094', 'B72604R8094', 'B72604R8100', 'B52501R80246', 'B52501R8137', 'B52501R8126', 'B72604R8120', 'B72604R8055', 'B72604R813', 'B72604R8089', 'B72604R8082', 'B72604R8118', 'B52501R8567', 'B72604R8080', 'B72604R8009', 'B72604R8061', 'B72604R8054', 'B52501R8005', 'B72604R8098', 'B72604R8030', 'B72604R8028', 'B72604R8039', 'B72604R8032', 'B72604R8131', 'B72604R8143', 'B72604R8129', 'B72604R8114', 'B72604R8042', 'B72604R8113', 'B72604R8010', 'B72604R8058', 'B72604R8037', 'B72604R8047', 'B72604R8102', 'B72604R8012', 'B72604R8053', 'B72604R8077', 'B52501R8192', 'B72604R8043', 'B72604R8064', 'B72604R8123', 'B72604R8117', 'B72604R8034', 'B72604R8029', 'B72604R8015', 'B72604R8040', 'B52501R8003']

d = set(d)

# %%
s.difference(d)
# Out:
# set()

# %%
d.difference(s)
# Out:
# {'B52501R8005',
#  'B52501R8016',
#  'B52501R8094',
#  'B52501R8126',
#  'B52501R8139',
#  'B72604R8016',
#  'B72604R8027',
#  'B72604R8028',
#  'B72604R8029',
#  'B72604R8037',
#  'B72604R8042',
#  'B72604R8057',
#  'B72604R8058',
#  'B72604R8082',
#  'B72604R8112',
#  'B72604R8118',
#  'B72604R8134'}

# %%
len(l)
# Out:
# 60

# %%
d.difference(l)
# Out:
# {'B52501R8016',
#  'B52501R80223',
#  'B52501R80246',
#  'B52501R8094',
#  'B52501R8126',
#  'B52501R8128',
#  'B52501R8137',
#  'B52501R8139',
#  'B72604R8015',
#  'B72604R8016',
#  'B72604R8027',
#  'B72604R8029',
#  'B72604R8037',
#  'B72604R8042',
#  'B72604R8058',
#  'B72604R8131'}

# %% [markdown]
# 'B52501R8016'  looks alright
#  'B52501R80223' looks alright
#  'B52501R80246' looks alright
#  'B52501R8094'  looks alright
#  'B52501R8126'  weird in the middle but looks alright
#  'B52501R8128'  grand
#  'B52501R8137'  grand
#
#
#  'B52501R8139'  funny stuff towards end but know fix for this
#  'B72604R8015'  bad but know problem
#  'B72604R8016'  bad same problem as above
#
#
#  'B72604R8027'  looks good
#  'B72604R8029'  looks good
#  'B72604R8037'  looks good
#  'B72604R8042'  looks mostly ok maybe ch1 fail? check
#  'B72604R8058'  looks good
#  'B72604R8131'  looks good

# %%
j = set(['B72604R8006', 'B72604R8044', 'B72604R8121', 'B72604R8095', 'B72604R8070', 'B72604R8016', 'B72604R8035', 'B72604R8112', 'B52501R8181', 'R72604R8035', 'B72604R8057', 'B72604R8048', 'B72604R8096', 'B72604R8138', 'B72604R8011', 'B52501R8221', 'B72604R8041', 'B72604R8146', 'B72604R8134', 'B72604R8122', 'B72604R8087', 'B52501R80209', 'B72604R8045', 'B72604R8067', 'B72604R8094', 'B72604R8100', 'B72604R8120', 'B72604R8055', 'B72604R813', 'B72604R8089', 'B72604R8118', 'B72604R8082', 'B52501R8567', 'B72604R8080', 'B72604R8009', 'B72604R8061', 'B72604R8054', 'B52501R8005', 'B72604R8098', 'B53501R8058', 'B72604R8030', 'B72604R8039', 'B72604R8028', 'B72604R8032', 'B72604R8143', 'B72604R8129', 'B72604R8114', 'B72604R8113', 'B72604R8010', 'B72604R8047', 'B72604R8102', 'B72604R8012', 'B72604R8053', 'B72604R8077', 'B52501R8192', 'B72604R8043', 'B72604R8064', 'B72604R8123', 'B72604R8117', 'B72604R8034', 'B72604R8040', 'B52501R8003'])

len(j)
# Out:
# 62

# %%
j.difference(l)
# Out:
# {'B53501R8058', 'B72604R8016'}

# %%
d.difference(j)
# Out:
# {'B52501R8016',
#  'B52501R80223',
#  'B52501R80246',
#  'B52501R8094',
#  'B52501R8126',
#  'B52501R8128',
#  'B52501R8137',
#  'B52501R8139',
#  'B72604R8015',
#  'B72604R8027',
#  'B72604R8029',
#  'B72604R8037',
#  'B72604R8042',
#  'B72604R8058',
#  'B72604R8131'}
